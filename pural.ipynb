# %%
import pdb
import nltk
import matplotlib as plt
import pandas as pd
import math
import numpy as np
nltk.download('brown')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
import nltk.tokenize
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
bw = nltk.corpus.brown.words()
bwt = nltk.corpus.brown.tagged_words()
bwts = nltk.corpus.brown.tagged_words(tagset='universal')

import string
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.

# %%
from nltk.corpus import brown

# %%
freq = nltk.defaultdict(int)
for word in [word.lower() for (word,t) in bwt if t.startswith('NN')]:
    freq[word] +=1
print ("\nWhich nouns are more common in their plural form, rather than their singular?\n")
for word in freq:
    if word+'s' in freq and freq[word+'s'] > freq[word]:
        #print ("%s  | pural frequency : %d | singular frequency : %d | pural word : %s" % (w, freq[w+'s'], freq[w],w+'s'))
        print ("(%s , %s)"  % (word ,word+'s'))
        print ("(%d , %d)"%(freq[word], freq[word+'s']))
# Out:
# Which nouns are more common in their plural form, rather than their singular?
#
# (term , terms)
# (76 , 160)
# (year , years)
# (656 , 949)
# (candidate , candidates)
# (34 , 38)
# (official , officials)
# (20 , 62)
# (bond , bonds)
# (43 , 47)
# (item , items)
# (55 , 72)
# (fund , funds)
# (62 , 95)
# (legislator , legislators)
# (7 , 20)
# (event , events)
# (81 , 101)
# (keynote , keynotes)
# (1 , 2)
# (revision , revisions)
# (8 , 9)
# (requirement , requirements)
# (27 , 83)
# (fee , fees)
# (16 , 29)
# (appointee , appointees)
# (2 , 5)
# (poll , polls)
# (9 , 10)
# (disclosure , disclosures)
# (2 , 4)
# (minute , minutes)
# (44 , 196)
# (worker , workers)
# (30 , 86)
# (employer , employers)
# (15 , 17)
# (student , students)
# (131 , 213)
# (dollar , dollars)
# (46 , 97)
# (appropriation , appropriations)
# (5 , 9)
# (leader , leaders)
# (74 , 107)
# (thing , things)
# (333 , 368)
# (rule , rules)
# (66 , 82)
# (hour , hours)
# (145 , 174)
# (element , elements)
# (52 , 107)
# (step , steps)
# (110 , 118)
# (diplomat , diplomats)
# (5 , 6)
# (affair , affairs)
# (33 , 84)
# (observer , observers)
# (16 , 20)
# (complication , complications)
# (4 , 5)
# (factor , factors)
# (71 , 105)
# (nation , nations)
# (139 , 175)
# (vehicle , vehicles)
# (35 , 53)
# (eye , eyes)
# (122 , 401)
# (expert , experts)
# (19 , 38)
# (voter , voters)
# (4 , 20)
# (member , members)
# (137 , 325)
# (product , products)
# (87 , 108)
# (remark , remarks)
# (29 , 46)
# (passenger , passengers)
# (14 , 21)
# (lip , lips)
# (18 , 69)
# (freeholder , freeholders)
# (1 , 3)
# (representative , representatives)
# (29 , 41)
# (wave , waves)
# (44 , 51)
# (visitor , visitors)
# (13 , 36)
# (scientist , scientists)
# (17 , 36)
# (object , objects)
# (53 , 62)
# (locale , locales)
# (3 , 4)
# (norm , norms)
# (7 , 24)
# (month , months)
# (130 , 189)
# (owner , owners)
# (33 , 35)
# (banker , bankers)
# (5 , 15)
# (panel , panels)
# (31 , 46)
# (princes , princess)
# (3 , 10)
# (commercial , commercials)
# (2 , 10)
# (native , natives)
# (10 , 11)
# (headache , headaches)
# (5 , 6)
# (towel , towels)
# (6 , 11)
# (headline , headlines)
# (4 , 7)
# (acre , acres)
# (10 , 44)
# (planner , planners)
# (2 , 13)
# (bomb , bombs)
# (33 , 35)
# (critic , critics)
# (25 , 26)
# (greeting , greetings)
# (4 , 6)
# (emerald , emeralds)
# (3 , 6)
# (denomination , denominations)
# (8 , 15)
# (immigrant , immigrants)
# (4 , 10)
# (defendant , defendants)
# (6 , 10)
# (plate , plates)
# (21 , 23)
# (error , errors)
# (36 , 44)
# (hit , hits)
# (12 , 15)
# (spectator , spectators)
# (9 , 13)
# (wing , wings)
# (17 , 27)
# (condition , conditions)
# (90 , 180)
# (win , wins)
# (1 , 3)
# (allowance , allowances)
# (16 , 25)
# (knee , knees)
# (35 , 38)
# (swelling , swellings)
# (1 , 2)
# (white , whites)
# (11 , 16)
# (longhorn , longhorns)
# (4 , 5)
# (leg , legs)
# (58 , 67)
# (yard , yards)
# (35 , 64)
# (star , stars)
# (25 , 29)
# (tactic , tactics)
# (4 , 20)
# (characteristic , characteristics)
# (24 , 52)
# (arm , arms)
# (93 , 121)
# (organ , organs)
# (12 , 14)
# (player , players)
# (21 , 29)
# (fan , fans)
# (14 , 19)
# (arrangement , arrangements)
# (34 , 38)
# (duffer , duffers)
# (1 , 2)
# (sport , sports)
# (17 , 48)
# (golfer , golfers)
# (3 , 4)
# (creature , creatures)
# (15 , 20)
# (pirate , pirates)
# (4 , 12)
# (groove , grooves)
# (2 , 3)
# (junior , juniors)
# (13 , 31)
# (hitter , hitters)
# (2 , 4)
# (bubble , bubbles)
# (12 , 13)
# (nerve , nerves)
# (12 , 22)
# (movie , movies)
# (29 , 31)
# (flower , flowers)
# (21 , 56)
# (drum , drums)
# (11 , 15)
# (megaton , megatons)
# (2 , 10)
# (angel , angels)
# (18 , 24)
# (asset , assets)
# (5 , 13)
# (troop , troops)
# (16 , 53)
# (sale , sales)
# (44 , 133)
# (slipper , slippers)
# (3 , 7)
# (thug , thugs)
# (1 , 2)
# (mile , miles)
# (48 , 169)
# (jurist , jurists)
# (3 , 4)
# (resident , residents)
# (8 , 20)
# (submarine , submarines)
# (15 , 20)
# (implication , implications)
# (10 , 22)
# (friend , friends)
# (130 , 161)
# (drawing , drawings)
# (12 , 21)
# (adviser , advisers)
# (6 , 12)
# (atom , atoms)
# (37 , 40)
# (narcotic , narcotics)
# (1 , 7)
# (eyebrow , eyebrows)
# (4 , 9)
# (emotion , emotions)
# (34 , 43)
# (cell , cells)
# (65 , 81)
# (cloud , clouds)
# (27 , 37)
# (neighbor , neighbors)
# (14 , 40)
# (deliberation , deliberations)
# (2 , 7)
# (suburb , suburbs)
# (13 , 18)
# (twin , twins)
# (6 , 12)
# (motorist , motorists)
# (2 , 5)
# (rebel , rebels)
# (15 , 16)
# (institution , institutions)
# (41 , 98)
# (commitment , commitments)
# (13 , 15)
# (obligation , obligations)
# (16 , 21)
# (guest , guests)
# (35 , 62)
# (ant , ants)
# (6 , 7)
# (ga , gas)
# (1 , 98)
# (robber , robbers)
# (2 , 6)
# (dividend , dividends)
# (6 , 8)
# (bird , birds)
# (25 , 57)
# (mill , mills)
# (10 , 14)
# (filbert , filberts)
# (1 , 2)
# (heel , heels)
# (9 , 23)
# (destroyer , destroyers)
# (2 , 3)
# (farmer , farmers)
# (23 , 33)
# (bomber , bombers)
# (8 , 22)
# (rocket , rockets)
# (7 , 13)
# (valve , valves)
# (3 , 4)
# (airfield , airfields)
# (5 , 6)
# (theologian , theologians)
# (5 , 9)
# (racketeer , racketeers)
# (2 , 3)
# (pier , piers)
# (3 , 5)
# (teamster , teamsters)
# (1 , 8)
# (meter , meters)
# (6 , 11)
# (card , cards)
# (26 , 36)
# (underwriter , underwriters)
# (1 , 4)
# (manufacturer , manufacturers)
# (23 , 47)
# (cleaner , cleaners)
# (5 , 8)
# (seed , seeds)
# (40 , 42)
# (maker , makers)
# (12 , 19)
# (instruction , instructions)
# (26 , 35)
# (stockholder , stockholders)
# (2 , 26)
# (shareholder , shareholders)
# (1 , 3)
# (dealer , dealers)
# (25 , 30)
# (competitor , competitors)
# (3 , 10)
# (picker , pickers)
# (1 , 3)
# (mineral , minerals)
# (12 , 14)
# (finding , findings)
# (11 , 34)
# (taxpayer , taxpayers)
# (11 , 21)
# (spouse , spouses)
# (3 , 4)
# (parent , parents)
# (15 , 91)
# (standard , standards)
# (31 , 74)
# (shoe , shoes)
# (14 , 44)
# (wrinkle , wrinkles)
# (2 , 7)
# (silhouette , silhouettes)
# (4 , 5)
# (tribe , tribes)
# (4 , 12)
# (cookie , cookies)
# (3 , 6)
# (feature , features)
# (30 , 75)
# (publisher , publishers)
# (9 , 11)
# (librarian , librarians)
# (5 , 6)
# (lecture , lectures)
# (14 , 15)
# (map , maps)
# (12 , 13)
# (aspect , aspects)
# (47 , 64)
# (lilac , lilacs)
# (1 , 3)
# (peasant , peasants)
# (7 , 12)
# (toy , toys)
# (4 , 10)
# (channel , channels)
# (15 , 23)
# (tank , tanks)
# (12 , 18)
# (painting , paintings)
# (27 , 36)
# (soldier , soldiers)
# (39 , 56)
# (musician , musicians)
# (23 , 41)
# (negotiation , negotiations)
# (6 , 20)
# (expectation , expectations)
# (11 , 23)
# (accomplishment , accomplishments)
# (7 , 10)
# (dimension , dimensions)
# (14 , 30)
# (employee , employees)
# (24 , 66)
# (outsider , outsiders)
# (3 , 8)
# (scholar , scholars)
# (15 , 27)
# (technique , techniques)
# (60 , 99)
# (implement , implements)
# (1 , 5)
# (restriction , restrictions)
# (8 , 27)
# (regulation , regulations)
# (14 , 29)
# (decree , decrees)
# (3 , 4)
# (mechanic , mechanics)
# (5 , 19)
# (mine , mines)
# (21 , 28)
# (limit , limits)
# (31 , 37)
# (moral , morals)
# (5 , 7)
# (southerner , southerners)
# (8 , 26)
# (guerrilla , guerrillas)
# (12 , 17)
# (modification , modifications)
# (4 , 6)
# (chore , chores)
# (7 , 16)
# (intellectual , intellectuals)
# (9 , 12)
# (reporter , reporters)
# (20 , 34)
# (trait , traits)
# (3 , 6)
# (vow , vows)
# (2 , 4)
# (weapon , weapons)
# (42 , 61)
# (rein , reins)
# (3 , 9)
# (undergraduate , undergraduates)
# (4 , 9)
# (experiment , experiments)
# (56 , 66)
# (applicant , applicants)
# (8 , 10)
# (roommate , roommates)
# (1 , 2)
# (trustee , trustees)
# (9 , 25)
# (endowment , endowments)
# (2 , 4)
# (finger , fingers)
# (40 , 66)
# (directive , directives)
# (2 , 4)
# (nut , nuts)
# (15 , 20)
# (bean , beans)
# (4 , 9)
# (investor , investors)
# (2 , 16)
# (ton , tons)
# (13 , 28)
# (resource , resources)
# (9 , 72)
# (citizen , citizens)
# (30 , 86)
# (slave , slaves)
# (30 , 44)
# (grassland , grasslands)
# (1 , 6)
# (silo , silos)
# (1 , 2)
# (faction , factions)
# (5 , 6)
# (liberal , liberals)
# (12 , 26)
# (conservative , conservatives)
# (3 , 4)
# (politician , politicians)
# (13 , 19)
# (fighter , fighters)
# (9 , 16)
# (imperfection , imperfections)
# (1 , 2)
# (recruit , recruits)
# (1 , 8)
# (customer , customers)
# (27 , 40)
# (root , roots)
# (26 , 27)
# (specialist , specialists)
# (16 , 19)
# (elephant , elephants)
# (7 , 10)
# (eagle , eagles)
# (5 , 6)
# (servant , servants)
# (19 , 22)
# (document , documents)
# (11 , 19)
# (speculation , speculations)
# (3 , 4)
# (purge , purges)
# (1 , 2)
# (employe , employes)
# (1 , 17)
# (teen-ager , teen-agers)
# (2 , 12)
# (being , beings)
# (30 , 36)
# (feather , feathers)
# (5 , 14)
# (blue , blues)
# (15 , 22)
# (tree , trees)
# (58 , 101)
# (outbreak , outbreaks)
# (2 , 3)
# (accommodation , accommodations)
# (1 , 8)
# (defect , defects)
# (3 , 13)
# (psychiatrist , psychiatrists)
# (4 , 5)
# (fabric , fabrics)
# (15 , 29)
# (limitation , limitations)
# (10 , 28)
# (component , components)
# (25 , 55)
# (volunteer , volunteers)
# (5 , 29)
# (consequence , consequences)
# (30 , 35)
# (prisoner , prisoners)
# (7 , 21)
# (occupant , occupants)
# (4 , 9)
# (youngster , youngsters)
# (8 , 18)
# (toe , toes)
# (7 , 19)
# (weave , weaves)
# (1 , 2)
# (highlight , highlights)
# (2 , 3)
# (brake , brakes)
# (2 , 7)
# (gadget , gadgets)
# (4 , 7)
# (symptom , symptoms)
# (5 , 14)
# (manifestation , manifestations)
# (6 , 9)
# (promoter , promoters)
# (1 , 4)
# (2-year-old , 2-year-olds)
# (2 , 3)
# (barrier , barriers)
# (9 , 17)
# (relation , relations)
# (63 , 102)
# (affiliation , affiliations)
# (4 , 5)
# (biscuit , biscuits)
# (2 , 5)
# (reservation , reservations)
# (8 , 9)
# (doing , doings)
# (4 , 6)
# (pilgrim , pilgrims)
# (4 , 6)
# (tentacle , tentacles)
# (1 , 2)
# (canon , canons)
# (5 , 6)
# (premise , premises)
# (7 , 8)
# (hue , hues)
# (1 , 2)
# (predecessor , predecessors)
# (5 , 6)
# (qualification , qualifications)
# (8 , 16)
# (custom , customs)
# (10 , 18)
# (dose , doses)
# (11 , 13)
# (researcher , researchers)
# (3 , 4)
# (expenditure , expenditures)
# (11 , 44)
# (commune , communes)
# (3 , 5)
# (national , nationals)
# (3 , 4)
# (cartoon , cartoons)
# (3 , 6)
# (hostage , hostages)
# (2 , 3)
# (sailor , sailors)
# (5 , 8)
# (blueprint , blueprints)
# (1 , 2)
# (ideal , ideals)
# (15 , 16)
# (export , exports)
# (8 , 11)
# (paragraph , paragraphs)
# (12 , 14)
# (vegetable , vegetables)
# (10 , 16)
# (crackpot , crackpots)
# (1 , 2)
# (outburst , outbursts)
# (2 , 6)
# (disc , discs)
# (6 , 7)
# (stamp , stamps)
# (3 , 4)
# (costume , costumes)
# (10 , 18)
# (projection , projections)
# (9 , 10)
# (cop , cops)
# (15 , 17)
# (nightclub , nightclubs)
# (2 , 4)
# (colleague , colleagues)
# (9 , 23)
# (quotation , quotations)
# (4 , 5)
# (circumstance , circumstances)
# (15 , 84)
# (collaborator , collaborators)
# (1 , 4)
# (riddle , riddles)
# (1 , 2)
# (ear , ears)
# (29 , 38)
# (poem , poems)
# (48 , 82)
# (technician , technicians)
# (6 , 12)
# (nuance , nuances)
# (1 , 3)
# (villain , villains)
# (3 , 4)
# (newlywed , newlyweds)
# (1 , 2)
# (salon , salons)
# (1 , 3)
# (observation , observations)
# (27 , 40)
# (photographer , photographers)
# (5 , 6)
# (lyric , lyrics)
# (7 , 15)
# (batterie , batteries)
# (1 , 3)
# (singer , singers)
# (8 , 13)
# (slack , slacks)
# (2 , 7)
# (treasure , treasures)
# (4 , 6)
# (forecast , forecasts)
# (3 , 5)
# (furnishing , furnishings)
# (3 , 9)
# (compliment , compliments)
# (3 , 4)
# (burn , burns)
# (5 , 13)
# (savage , savages)
# (1 , 6)
# (classic , classics)
# (5 , 9)
# (mean , means)
# (12 , 191)
# (seeker , seekers)
# (1 , 3)
# (listener , listeners)
# (10 , 20)
# (vista , vistas)
# (2 , 3)
# (final , finals)
# (1 , 10)
# (loudspeaker , loudspeakers)
# (1 , 2)
# (gasp , gasps)
# (2 , 5)
# (aspiration , aspirations)
# (3 , 12)
# (prime , primes)
# (1 , 2)
# (mountain , mountains)
# (33 , 43)
# (peacock , peacocks)
# (2 , 4)
# (cart , carts)
# (4 , 5)
# (sailboat , sailboats)
# (1 , 3)
# (waterway , waterways)
# (2 , 3)
# (dam , dams)
# (2 , 3)
# (race-driver , race-drivers)
# (3 , 4)
# (fat , fats)
# (13 , 19)
# (solid , solids)
# (7 , 13)
# (ingredient , ingredients)
# (6 , 9)
# (molecule , molecules)
# (6 , 9)
# (user , users)
# (4 , 6)
# (boot , boots)
# (10 , 20)
# (scripture , scriptures)
# (4 , 11)
# (follower , followers)
# (3 , 17)
# (nun , nuns)
# (2 , 4)
# (periodical , periodicals)
# (4 , 5)
# (oyster , oysters)
# (6 , 8)
# (bound , bounds)
# (3 , 10)
# (merchant , merchants)
# (18 , 22)
# (leave , leaves)
# (10 , 23)
# (ruler , rulers)
# (3 , 9)
# (leaflet , leaflets)
# (1 , 3)
# (topic , topics)
# (9 , 10)
# (participant , participants)
# (4 , 7)
# (lament , laments)
# (1 , 2)
# (interval , intervals)
# (18 , 25)
# (planet , planets)
# (21 , 22)
# (realtor , realtors)
# (5 , 19)
# (buyer , buyers)
# (2 , 5)
# (professional , professionals)
# (6 , 10)
# (chunk , chunks)
# (2 , 5)
# (vineyard , vineyards)
# (2 , 5)
# (convert , converts)
# (3 , 5)
# (metaphysic , metaphysics)
# (3 , 12)
# (drug , drugs)
# (24 , 28)
# (mystic , mystics)
# (1 , 3)
# (believer , believers)
# (4 , 5)
# (speculator , speculators)
# (1 , 2)
# (pupil , pupils)
# (20 , 25)
# (deltoid , deltoids)
# (1 , 2)
# (flare , flares)
# (3 , 5)
# (facet , facets)
# (2 , 9)
# (blossom , blossoms)
# (3 , 7)
# (grower , growers)
# (1 , 3)
# (egg , eggs)
# (12 , 35)
# (vitamin , vitamins)
# (5 , 10)
# (performer , performers)
# (7 , 13)
# (giant , giants)
# (6 , 21)
# (corp , corps)
# (1 , 103)
# (trailer , trailers)
# (11 , 12)
# (plastic , plastics)
# (25 , 31)
# (rating , ratings)
# (6 , 9)
# (marina , marinas)
# (3 , 7)
# (spacer , spacers)
# (2 , 5)
# (measurement , measurements)
# (34 , 54)
# (pacer , pacers)
# (1 , 3)
# (trader , traders)
# (8 , 26)
# (thicket , thickets)
# (1 , 2)
# (adapter , adapters)
# (1 , 2)
# (rim-fire , rim-fires)
# (2 , 3)
# (rib , ribs)
# (1 , 11)
# (preserve , preserves)
# (4 , 8)
# (clove , cloves)
# (1 , 2)
# (adventure , adventures)
# (13 , 14)
# (photo , photos)
# (5 , 7)
# (fill-in , fill-ins)
# (1 , 2)
# (landmark , landmarks)
# (3 , 7)
# (spice , spices)
# (2 , 3)
# (sultan , sultans)
# (3 , 4)
# (favorite , favorites)
# (4 , 12)
# (frank , franks)
# (4 , 8)
# (tablespoon , tablespoons)
# (6 , 7)
# (pound , pounds)
# (26 , 44)
# (plaque , plaques)
# (2 , 4)
# (stain , stains)
# (4 , 9)
# (shaker , shakers)
# (2 , 3)
# (sock , socks)
# (3 , 7)
# (chop , chops)
# (2 , 3)
# (nail , nails)
# (6 , 14)
# (batten , battens)
# (3 , 15)
# (trimming , trimmings)
# (1 , 4)
# (particle , particles)
# (21 , 42)
# (compound , compounds)
# (9 , 15)
# (gable , gables)
# (2 , 3)
# (lag , lags)
# (1 , 2)
# (booklet , booklets)
# (1 , 2)
# (cutter , cutters)
# (4 , 6)
# (tavern , taverns)
# (2 , 4)
# (advertisement , advertisements)
# (2 , 3)
# (insect , insects)
# (14 , 23)
# (installation , installations)
# (12 , 16)
# (drier , driers)
# (1 , 3)
# (investigator , investigators)
# (4 , 13)
# (watershed , watersheds)
# (3 , 4)
# (make , makes)
# (3 , 4)
# (bristle , bristles)
# (2 , 3)
# (progression , progressions)
# (2 , 3)
# (associate , associates)
# (7 , 14)
# (somersault , somersaults)
# (2 , 3)
# (gymnast , gymnasts)
# (1 , 4)
# (push-up , push-ups)
# (3 , 4)
# (backbend , backbends)
# (1 , 2)
# (handstand , handstands)
# (1 , 3)
# (wavelength , wavelengths)
# (4 , 6)
# (lung , lungs)
# (16 , 20)
# (indicator , indicators)
# (8 , 9)
# (elector , electors)
# (2 , 3)
# (additive , additives)
# (3 , 4)
# (shipment , shipments)
# (2 , 16)
# (milligram , milligrams)
# (5 , 21)
# (gram , grams)
# (9 , 18)
# (enzyme , enzymes)
# (6 , 11)
# (tranquilizer , tranquilizers)
# (1 , 4)
# (hike , hikes)
# (3 , 4)
# (concessionaire , concessionaires)
# (2 , 7)
# (camper , campers)
# (3 , 9)
# (contributor , contributors)
# (2 , 6)
# (gallon , gallons)
# (5 , 6)
# (saving , savings)
# (3 , 23)
# (billboard , billboards)
# (1 , 2)
# (stair , stairs)
# (2 , 47)
# (carrier , carriers)
# (9 , 11)
# (third , thirds)
# (2 , 4)
# (explosive , explosives)
# (1 , 3)
# (counterpart , counterparts)
# (9 , 11)
# (psychologist , psychologists)
# (10 , 11)
# (insecticide , insecticides)
# (1 , 2)
# (leak , leaks)
# (2 , 3)
# (airline , airlines)
# (2 , 5)
# (helmet , helmets)
# (1 , 2)
# (doll , dolls)
# (10 , 12)
# (calorie , calories)
# (1 , 7)
# (resultant , resultants)
# (1 , 5)
# (crusader , crusaders)
# (1 , 2)
# (proponent , proponents)
# (2 , 6)
# (gynecologist , gynecologists)
# (1 , 2)
# (teenager , teenagers)
# (2 , 5)
# (bracket , brackets)
# (1 , 2)
# (ailment , ailments)
# (4 , 6)
# (practitioner , practitioners)
# (2 , 6)
# (spike , spikes)
# (1 , 2)
# (ghoul , ghouls)
# (1 , 2)
# (classmate , classmates)
# (3 , 4)
# (predisposition , predispositions)
# (4 , 9)
# (appliance , appliances)
# (5 , 8)
# (binder , binders)
# (1 , 2)
# (anti-semite , anti-semites)
# (2 , 3)
# (recrimination , recriminations)
# (1 , 3)
# (axe , axes)
# (6 , 7)
# (patron , patrons)
# (4 , 9)
# (confederate , confederates)
# (1 , 2)
# (comrade , comrades)
# (4 , 10)
# (propagandist , propagandists)
# (3 , 4)
# (trouser , trousers)
# (3 , 7)
# (jowl , jowls)
# (2 , 4)
# (concession , concessions)
# (3 , 7)
# (swell , swells)
# (1 , 4)
# (organism , organisms)
# (6 , 7)
# (grenade , grenades)
# (3 , 6)
# (adherent , adherents)
# (1 , 5)
# (eclipse , eclipses)
# (2 , 4)
# (knuckle , knuckles)
# (2 , 7)
# (nostril , nostrils)
# (1 , 3)
# (felon , felons)
# (1 , 2)
# (bite , bites)
# (3 , 6)
# (bee , bees)
# (11 , 15)
# (sediment , sediments)
# (3 , 4)
# (shortcut , shortcuts)
# (1 , 2)
# (abolitionist , abolitionists)
# (1 , 4)
# (memoir , memoirs)
# (2 , 4)
# (tenant , tenants)
# (5 , 9)
# (plain , plains)
# (7 , 14)
# (schoolmate , schoolmates)
# (1 , 2)
# (adjective , adjectives)
# (2 , 4)
# (soybean , soybeans)
# (5 , 6)
# (byproduct , byproducts)
# (2 , 3)
# (constituent , constituents)
# (5 , 10)
# (almond , almonds)
# (1 , 3)
# (bead , beads)
# (1 , 4)
# (carrot , carrots)
# (1 , 4)
# (oilseed , oilseeds)
# (1 , 4)
# (hoof , hoofs)
# (2 , 7)
# (stripe , stripes)
# (4 , 5)
# (flame , flames)
# (13 , 14)
# (paw , paws)
# (2 , 3)
# (enthusiast , enthusiasts)
# (2 , 3)
# (armament , armaments)
# (1 , 4)
# (striving , strivings)
# (1 , 3)
# (peer , peers)
# (6 , 7)
# (dolphin , dolphins)
# (1 , 4)
# (northerner , northerners)
# (4 , 5)
# (franc , francs)
# (1 , 3)
# (fragment , fragments)
# (6 , 10)
# (runner , runners)
# (1 , 5)
# (puddle , puddles)
# (1 , 2)
# (aborigine , aborigines)
# (7 , 8)
# (cosmetic , cosmetics)
# (1 , 7)
# (orchard , orchards)
# (3 , 5)
# (attribute , attributes)
# (4 , 11)
# (escapade , escapades)
# (1 , 2)
# (footstep , footsteps)
# (3 , 8)
# (serpent , serpents)
# (2 , 3)
# (meteor , meteors)
# (3 , 4)
# (concentrate , concentrates)
# (1 , 5)
# (ethic , ethics)
# (4 , 19)
# (creeper , creepers)
# (1 , 2)
# (bough , boughs)
# (2 , 4)
# (bud , buds)
# (2 , 5)
# (vine , vines)
# (4 , 8)
# (gutter , gutters)
# (1 , 2)
# (hub , hubs)
# (1 , 2)
# (backyard , backyards)
# (2 , 3)
# (ill , ills)
# (1 , 9)
# (defender , defenders)
# (3 , 6)
# (vault , vaults)
# (2 , 6)
# (conqueror , conquerors)
# (1 , 2)
# (insinuation , insinuations)
# (2 , 3)
# (eccentric , eccentrics)
# (1 , 2)
# (maneuver , maneuvers)
# (3 , 8)
# (generalist , generalists)
# (1 , 2)
# (inmate , inmates)
# (1 , 6)
# (absolute , absolutes)
# (1 , 3)
# (dislocation , dislocations)
# (1 , 2)
# (descendant , descendants)
# (2 , 4)
# (suitor , suitors)
# (1 , 3)
# (contour , contours)
# (6 , 15)
# (epicycle , epicycles)
# (1 , 6)
# (disciple , disciples)
# (4 , 5)
# (determinant , determinants)
# (1 , 2)
# (precept , precepts)
# (1 , 3)
# (entertainer , entertainers)
# (2 , 3)
# (prop , props)
# (2 , 6)
# (meditation , meditations)
# (2 , 4)
# (endearment , endearments)
# (1 , 2)
# (delegate , delegates)
# (4 , 16)
# (bushel , bushels)
# (1 , 4)
# (foreigner , foreigners)
# (4 , 13)
# (pamphlet , pamphlets)
# (2 , 9)
# (prerogative , prerogatives)
# (1 , 2)
# (feud , feuds)
# (1 , 2)
# (tear , tears)
# (2 , 34)
# (probe , probes)
# (1 , 3)
# (supporter , supporters)
# (3 , 8)
# (evocation , evocations)
# (1 , 2)
# (barricade , barricades)
# (2 , 4)
# (spade , spades)
# (3 , 4)
# (ray , rays)
# (3 , 7)
# (tidbit , tidbits)
# (1 , 2)
# (bidder , bidders)
# (2 , 3)
# (libertie , liberties)
# (1 , 8)
# (interrelationship , interrelationships)
# (1 , 2)
# (apologie , apologies)
# (1 , 4)
# (conformist , conformists)
# (2 , 3)
# (reinforcement , reinforcements)
# (2 , 3)
# (subordinate , subordinates)
# (1 , 9)
# (disadvantage , disadvantages)
# (4 , 9)
# (hulk , hulks)
# (2 , 3)
# (survivalist , survivalists)
# (1 , 2)
# (libertine , libertines)
# (1 , 2)
# (allusion , allusions)
# (3 , 5)
# (lodging , lodgings)
# (1 , 2)
# (generalization , generalizations)
# (4 , 7)
# (exploit , exploits)
# (1 , 4)
# (bootlegger , bootleggers)
# (1 , 2)
# (epithet , epithets)
# (2 , 7)
# (robot , robots)
# (1 , 3)
# (dystopia , dystopias)
# (2 , 8)
# (ad , ads)
# (4 , 10)
# (brave , braves)
# (1 , 3)
# (improvisation , improvisations)
# (1 , 2)
# (aberration , aberrations)
# (3 , 5)
# (bruise , bruises)
# (2 , 8)
# (cooperative , cooperatives)
# (1 , 10)
# (headquarter , headquarters)
# (1 , 65)
# (assessor , assessors)
# (2 , 20)
# (authorization , authorizations)
# (2 , 6)
# (manual , manuals)
# (2 , 4)
# (hydride , hydrides)
# (2 , 3)
# (resistor , resistors)
# (3 , 7)
# (terminal , terminals)
# (3 , 4)
# (infestation , infestations)
# (2 , 4)
# (rupee , rupees)
# (6 , 14)
# (receipt , receipts)
# (4 , 7)
# (proceeding , proceedings)
# (5 , 18)
# (alien , aliens)
# (2 , 3)
# (dependent , dependents)
# (1 , 2)
# (antecedent , antecedents)
# (1 , 2)
# (polymer , polymers)
# (1 , 4)
# (deadlines , deadliness)
# (1 , 2)
# (centimeter , centimeters)
# (2 , 8)
# (lobe , lobes)
# (3 , 5)
# (pore , pores)
# (2 , 3)
# (ripple , ripples)
# (4 , 5)
# (shunt , shunts)
# (1 , 5)
# (parameter , parameters)
# (7 , 8)
# (ellipsoid , ellipsoids)
# (1 , 4)
# (ion , ions)
# (5 , 9)
# (active , actives)
# (6 , 8)
# (surfactant , surfactants)
# (1 , 2)
# (polyphosphate , polyphosphates)
# (1 , 5)
# (reagent , reagents)
# (1 , 3)
# (sensor , sensors)
# (3 , 6)
# (meteorite , meteorites)
# (6 , 8)
# (microorganism , microorganisms)
# (1 , 12)
# (honeybee , honeybees)
# (2 , 4)
# (catkin , catkins)
# (2 , 5)
# (bumblebee , bumblebees)
# (2 , 10)
# (parasite , parasites)
# (1 , 4)
# (down , downs)
# (1 , 3)
# (andrena , andrenas)
# (1 , 4)
# (rattlesnake , rattlesnakes)
# (3 , 5)
# (herpetologist , herpetologists)
# (1 , 2)
# (geologist , geologists)
# (2 , 3)
# (bronchiole , bronchioles)
# (4 , 9)
# (duct , ducts)
# (1 , 6)
# (lobule , lobules)
# (1 , 2)
# (antagonist , antagonists)
# (3 , 4)
# (marking , markings)
# (1 , 2)
# (protease , proteases)
# (1 , 4)
# (steroid , steroids)
# (1 , 2)
# (extract , extracts)
# (1 , 3)
# (conjugate , conjugates)
# (10 , 14)
# (u , us)
# (3 , 4)
# (variable , variables)
# (11 , 26)
# (cube , cubes)
# (1 , 4)
# (tangent , tangents)
# (4 , 6)
# (secant , secants)
# (12 , 16)
# (advisor , advisors)
# (1 , 5)
# (sacrament , sacraments)
# (1 , 2)
# (wandering , wanderings)
# (1 , 3)
# (referral , referrals)
# (6 , 8)
# (dynamic , dynamics)
# (1 , 4)
# (subsystem , subsystems)
# (2 , 10)
# (survivor , survivors)
# (1 , 13)
# (tenement , tenements)
# (2 , 3)
# (supermarket , supermarkets)
# (1 , 3)
# (axiom , axioms)
# (1 , 2)
# (inflection , inflections)
# (3 , 4)
# (syllable , syllables)
# (1 , 9)
# (adverb , adverbs)
# (1 , 2)
# (noun , nouns)
# (1 , 3)
# (monosyllable , monosyllables)
# (1 , 2)
# (consonant , consonants)
# (2 , 4)
# (verb , verbs)
# (4 , 7)
# (ramification , ramifications)
# (1 , 3)
# (broker , brokers)
# (1 , 4)
# (injunction , injunctions)
# (3 , 5)
# (litigant , litigants)
# (2 , 3)
# (repulsion , repulsions)
# (1 , 2)
# (miner , miners)
# (1 , 5)
# (vase , vases)
# (4 , 11)
# (telegrapher , telegraphers)
# (3 , 5)
# (grocer , grocers)
# (1 , 3)
# (warrior , warriors)
# (5 , 7)
# (advertiser , advertisers)
# (1 , 5)
# (grape , grapes)
# (3 , 7)
# (retailer , retailers)
# (1 , 5)
# (admonition , admonitions)
# (1 , 3)
# (rendition , renditions)
# (1 , 3)
# (kenning , kennings)
# (1 , 10)
# (congratulation , congratulations)
# (1 , 7)
# (rdw , rdws)
# (2 , 3)
# (burglar , burglars)
# (1 , 2)
# (peptide , peptides)
# (1 , 2)
# (tektite , tektites)
# (1 , 5)
# (crater , craters)
# (2 , 5)
# (ligand , ligands)
# (1 , 2)
# (crystallite , crystallites)
# (1 , 3)
# (sausage , sausages)
# (1 , 5)
# (transformer , transformers)
# (1 , 2)
# (interface , interfaces)
# (3 , 5)
# (grit , grits)
# (1 , 3)
# (fin , fins)
# (2 , 5)
# (specification , specifications)
# (3 , 9)
# (coordinate , coordinates)
# (2 , 5)
# (overhang , overhangs)
# (1 , 2)
# (romantic , romantics)
# (1 , 5)
# (bastard , bastards)
# (12 , 14)
# (elder , elders)
# (5 , 9)
# (rut , ruts)
# (1 , 2)
# (superior , superiors)
# (1 , 4)
# (soothsayer , soothsayers)
# (1 , 2)
# (redcoat , redcoats)
# (6 , 9)
# (mug , mugs)
# (1 , 2)
# (shrub , shrubs)
# (1 , 4)
# (firecracker , firecrackers)
# (1 , 2)
# (lamentation , lamentations)
# (1 , 2)
# (draper , drapers)
# (1 , 2)
# (moccasin , moccasins)
# (1 , 2)
# (shred , shreds)
# (1 , 5)
# (barrack , barracks)
# (1 , 3)
# (stray , strays)
# (1 , 6)
# (cuff , cuffs)
# (1 , 2)
# (stump , stumps)
# (2 , 5)
# (perturbation , perturbations)
# (1 , 2)
# (hinge , hinges)
# (1 , 3)
# (dresser , dressers)
# (1 , 2)
# (relative , relatives)
# (1 , 22)
# (gangster , gangsters)
# (2 , 4)
# (bug , bugs)
# (3 , 4)
# (sole , soles)
# (2 , 5)
# (banshee , banshees)
# (1 , 2)
# (siren , sirens)
# (1 , 2)
# (skylight , skylights)
# (1 , 2)
# (uprising , uprisings)
# (1 , 2)
# (gut , guts)
# (1 , 9)
# (sedan , sedans)
# (2 , 4)
# (highland , highlands)
# (1 , 6)
# (pheasant , pheasants)
# (1 , 2)
# (jewel , jewels)
# (1 , 3)
# (lapel , lapels)
# (1 , 2)
# (mammal , mammals)
# (1 , 3)
# (rogue , rogues)
# (1 , 2)
# (gust , gusts)
# (1 , 3)
# (pillar , pillars)
# (2 , 5)
# (personage , personages)
# (1 , 3)
# (auditor , auditors)
# (1 , 4)
# (happening , happenings)
# (2 , 5)
# (strap , straps)
# (1 , 2)
# (settler , settlers)
# (3 , 12)
# (claw , claws)
# (1 , 3)
# (chant , chants)
# (1 , 3)
# (duck , ducks)
# (2 , 4)
# (gunner , gunners)
# (1 , 2)
# (clod , clods)
# (1 , 4)
# (pebble , pebbles)
# (1 , 3)
# (caller , callers)
# (2 , 3)
# (triplet , triplets)
# (1 , 3)
# (spoke , spokes)
# (1 , 2)
# (overall , overalls)
# (2 , 5)
# (sneaker , sneakers)
# (2 , 3)
# (cheekbone , cheekbones)
# (1 , 5)
# (invader , invaders)
# (1 , 5)
# (bicep , biceps)
# (1 , 3)
# (tonic , tonics)
# (1 , 2)
# (diver , divers)
# (1 , 2)
# (skipper , skippers)
# (1 , 2)
# (urn , urns)
# (1 , 2)
# (loin , loins)
# (1 , 2)
# (giggle , giggles)
# (1 , 4)
# (critter , critters)
# (1 , 3)
# (bun , buns)
# (1 , 8)
# (eyelid , eyelids)
# (1 , 7)
# (moth , moths)
# (1 , 2)
# (cowbird , cowbirds)
# (1 , 3)
# (dragon , dragons)
# (1 , 2)
# (magnum , magnums)
# (1 , 2)
# (azalea , azaleas)
# (2 , 3)
# (vendor , vendors)
# (1 , 2)
# (pink , pinks)
# (1 , 2)
# (dune , dunes)
# (1 , 8)
# (pajama , pajamas)
# (1 , 3)
# (addict , addicts)
# (1 , 4)
# (barbarian , barbarians)
# (1 , 4)
# (traitor , traitors)
# (2 , 4)
# (brothel , brothels)
# (1 , 2)
# (abstract , abstracts)
# (1 , 4)
# (tick , ticks)
# (1 , 2)
# (belonging , belongings)
# (1 , 4)

# %%
print ("\nWhich word has the greatest number of distinct tags? What are they, and what do they represent\n")
word_tag = nltk.defaultdict(set)
for word,t  in  bwt:
    word_tag[word.lower()].add(t)
m = max(len(word_tag[word]) for word in word_tag)
print  ([(word, t) for word,t  in word_tag.items() if len(t) == m])

#        List tags in order of decreasing frequency. What do the 20 most frequent tags represent?
print ("\nTop 20 tags in decreasing frequency\n")

tagfd = nltk.FreqDist(t for (word,t)  in  bwt)
print (tagfd.most_common(20))

print ("\nTop 20 simplified tags in decreasing frequency\n")

tagfd = nltk.FreqDist(t for (word,t)  in  bwts)
print (tagfd.most_common(20))

#        Which tags are nouns most commonly found after? What do these tags represent? 

print ("\nTop 20 simplified tags that proceed nouns\n")
tagbigram =nltk.bigrams(t for (word,t)  in  bwts)

afterN = nltk.FreqDist(t1 for (t1,t2)  in  tagbigram if t2 == 'NOUN')

print (afterN.most_common(20))
# Out:
# Which word has the greatest number of distinct tags? What are they, and what do they represent
#
# [('that', {'QL', 'DT-NC', 'DT', 'NIL', 'DT-HL', 'WPO-NC', 'CS', 'WPO', 'CS-HL', 'WPS', 'CS-NC', 'WPS-TL', 'WPS-HL', 'DT-TL', 'WPS-NC'})]
#
# Top 20 tags in decreasing frequency
#
# [('NN', 152470), ('IN', 120557), ('AT', 97959), ('JJ', 64028), ('.', 60638), (',', 58156), ('NNS', 55110), ('CC', 37718), ('RB', 36464), ('NP', 34476), ('VB', 33693), ('VBN', 29186), ('VBD', 26167), ('CS', 22143), ('PPS', 18253), ('VBG', 17893), ('PP$', 16872), ('TO', 14918), ('PPSS', 13802), ('CD', 13510)]
#
# Top 20 simplified tags in decreasing frequency
#
# [('NOUN', 275558), ('VERB', 182750), ('.', 147565), ('ADP', 144766), ('DET', 137019), ('ADJ', 83721), ('ADV', 56239), ('PRON', 49334), ('CONJ', 38151), ('PRT', 29829), ('NUM', 14874), ('X', 1386)]
#
# Top 20 simplified tags that proceed nouns
#
# [('DET', 85845), ('ADJ', 54653), ('NOUN', 41309), ('ADP', 37418), ('.', 20084), ('VERB', 17851), ('CONJ', 9294), ('NUM', 5668), ('ADV', 1851), ('PRT', 1068), ('PRON', 440), ('X', 77)]

# %% [markdown]
# 4. Write a program to find all words that occur at least three times in the Brown
#
# Corpus.(Hint : Use NLTK  corpus )

# %%
all_unique_brown=set(brown.words())
brown_fd=nltk.FreqDist(brown.words())
atleast_3_times=[word for word in all_unique_brown if brown_fd[word]>2]
print(atleast_3_times)
# Out:
# ['NW', 'Ah', 'Shreveport', 'supplant', 'crime', 'propose', 'treasure', 'flax', 'jealousy', 'ecstasy', 'Matunuck', 'alabaster', 'effluent', 'ugly', 'virtuoso', 'Roger', 'Targo', 'Berman', 'care', 'seventh', 'pockets', 'abstracts', 'co-optation', 'adjectives', 'legislators', 'abdominal', 'picnic', "Army's", 'assert', 'Stands', 'caused', 'exceed', 'almost', 'embodiment', 'limiting', 'Cologne', 'manufacturing', 'frightful', 'extensions', 'diffusion', 'icy', 'vaguely', 'alibi', 'BTU', 'rocking', 'jure', 'questioning', 'Stein', 'dome', 'Midway', 'emerge', 'murdered', "Krim's", 'Question', 'Subject', 'Mynheer', 'grille', 'Raton', 'astronomical', 'macro-instructions', 'megatons', 'muscles', '52', 'Application', 'dispute', 'colors', 'crowing', 'gin', 'auditors', 'raced', "it'll", 'blot', 'tiniest', '300,000', 'cookie', 'aerial', 'Rich', 'tubes', 'Second', 'illumination', 'steal', "we'd", 'Pass', 'lewd', 'eliminates', 'powders', '1953', 'colts', 'butter', 'tenants', 'Hole', 'Westfield', 'chambers', 'rattlesnakes', 'clung', 'mounting', 'scabbard', 'desegregated', 'adversely', 'Lew', 'insisting', 'kwhr', 'Burgundy', 'Observatory', 'divisible', 'Chemical', 'researchers', 'brotherhood', 'trot', 'slaves', 'formulation', 'Common', 'wing', 'World', 'inflict', 'symbolic', 'answering', 'Apart', 'scrutiny', 'rations', 'leaves', 'tapes', 'objectives', "Sherman's", 'mapping', "Government's", 'airplanes', 'greeted', 'bids', 'creation', 'retorted', '29', "He'll", 'returned', 'fed', 'radios', 'bristling', 'contraction', 'preserved', 'crazily', 'dilution', 'forecasts', 'intertwined', 'door', 'Orchestra', 'evident', 'Elinor', 'touring', 'equivalence', 'anyone', 'explaining', '8,000', 'loveliness', 'Springfield', '1,000', '2:01.1', 'corridor', 'Prior', 'Four', 'philanthropic', "O'Neill", 'sauce', 'shoot', 'Clubs', 'collaborators', 'boot', 'Strong', 'neglecting', 'settled', 'Matson', 'Tiepolo', 'advertised', 'tantamount', 'sighted', 'Parts', 'analyzing', 'terror', 'district', 'our', 'immanent', 'bend', 'guessed', 'predictable', 'nurture', 'bandits', 'Baird', 'forms', 'catalogued', 'all', 'packet', 'plastered', 'questions', 'Prize', 'likelihood', 'rebellion', 'periods', 'voters', 'cupful', 'est', 'satisfaction', 'affectionate', 'ossification', 'spaciousness', 'Thomas', 'medicine', 'Marlowe', 'Lumber', 'Each', 'nice', 'amongst', 'metropolis', 'deserted', 'abandoning', 'watching', 'proffered', 'headmaster', 'Rouge', 'soils', 'zeal', 'thrilling', 'rumor', ':', 'Garry', 'magically', 'freshman', 'panes', 'relativity', 'flowered', 'chip', 'Susie', 'bequests', 'Lizzie', 'horizontally', 'Universal', 'arise', 'tiny', 'drift', 'microseconds', 'soaking', 'example', 'clerks', 'policy', 'rally', 'skirts', 'uppon', 'autocollimator', 'moderator', 'Thayer', 'repeats', 'Moslem', 'Board', 'wholesome', 'adorable', 'serene', 'fishing', 'explanatory', 'bogey', 'Playhouse', 'Jerusalem', 'funny', 'automobiles', 'glued', 'auction', 'successive', 'minute', 'completes', 'Medical', 'Glen', 'winged', 'symbolically', 'authoritarian', 'Format', 'title', 'nearer', 'alliance', 'located', 'LaGuardia', 'isotonic', 'gazing', 'inappropriate', 'nominal', 'ministering', 'muzzle', 'pretend', 'lessen', 'belied', 'sleeve', 'Louis', 'jury', 'Republicans', 'comparatively', 'awesome', 'hurricane', 'Grady', 'tipped', 'stiffly', 'Hanford', 'rental', 'inn', 'flakes', 'sadness', 'socio-economic', 'Queens', 'FITC', 'scope', 'bound', "B.'s", 'iodine', 'resent', 'pane', 'Denton', 'apart', 'forearm', 'termination', 'congealed', 'crouched', 'Heydrich', 'Herter', 'set', 'primitive', 'rider', '180', "Vernon's", 'hard-surface', 'octagonal', 'Heavy', 'slight', 'hopples', 'Tones', 'martyr', 'repressed', 'caste', 'tapped', 'pan', 'woe', 'strewn', 'Mystery', 'poorest', 'unnamed', 'tell-tale', 'eight', 'cushioning', 'Arts', "Joe's", 'Also', 'erect', 'discussion', 'bandages', 'breakdowns', 'conduct', 'good-bye', 'vessel', 'outpost', 'immediately', 'concurrent', "po'k", 'mulch', 'spoon', 'produce', 'python', 'sensible ...
